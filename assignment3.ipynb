# %% [markdown]
# Q1

# %%
# %%writefile q1.cu
# #include <stdio.h>
#
# __global__ void add(int *a, int *b, int *c)
# {
#   int i = blockIdx.x*blockDim.x + threadIdx.x;
#   c[i] = a[i] + b[i];
# }
#
# int main()
# {
#   int N = 1024;
#   int a[1024];
#   int b[1024];
#   int c[1024];
#
#   for (int i = 0; i < N; i++)
#   {
#     a[i] = i*1.0f;
#     b[i] = i*2.0f;
#   }
#   int *d_a, *d_b, *d_c;
#   int size = N*sizeof(int);
#   cudaMalloc((void **) &d_a, size);
#   cudaMalloc((void **) &d_b, size);
#   cudaMalloc((void **) &d_c, size);
#
#   cudaMemcpy(d_a, a, size, cudaMemcpyHostToDevice);
#   cudaMemcpy(d_b, b, size, cudaMemcpyHostToDevice);
#
#   add<<<32, 32>>>(d_a, d_b, d_c);
#
#   cudaMemcpy(c, d_c, size, cudaMemcpyDeviceToHost);
#   for (int i = 0; i < 5; i++)
#   {
#     printf("C[%d] = %d\n", i, c[i]);
#   }
#   cudaFree(d_a);
#   cudaFree(d_b);
#   cudaFree(d_c);
#   return 0;
# }
# Out:
# Overwriting q1.cu

# %%
# !nvcc -arch=sm_75 q1.cu -o q1

# %%
# !./q1
# Out:
# C[0] = 0
# C[1] = 3
# C[2] = 6
# C[3] = 9
# C[4] = 12

# %% [markdown]
# Q2

# %%
# %%writefile q2.cu
# #include <iostream>
# #include <thrust/device_vector.h>
# #include <thrust/transform.h>
#
# int main()
# {
#   int N = 1024;
#   thrust::device_vector<int> A(N);
#   thrust::device_vector<int> B(N);
#   thrust::device_vector<int> C(N);
#
#   for (int i = 0; i < N; i++)
#   {
#     A[i] = i*1.0f;
#     B[i] = i*2.0f;
#   }
#   thrust::transform(A.begin(), A.end(), B.begin(), C.begin(), thrust::plus<int>());
#
#   for (int i = 0; i < 5; i++)
#   {
#     std::cout << C[i] << std::endl;
#   }
#
# }
# Out:
# Overwriting q2.cu

# %%
# !nvcc -arch=sm_75 q2.cu -o q2

# %%
# !./q2
# Out:
# 0
# 3
# 6
# 9
# 12

# %%
# %%writefile q3.cu
# #include <thrust/device_vector.h>
# #include <thrust/inner_product.h>
# #include <iostream>
# using namespace std;
#
# int main() {
#     int N = 1024;
#
#     thrust::device_vector<int> A(N, 1);
#     thrust::device_vector<int> B(N, 2);
#
#     int result = thrust::inner_product(A.begin(), A.end(), B.begin(), 0);
#
#     cout << "Dot Product: " << result << endl;
# }
# Out:
# Overwriting q3.cu

# %%
# !nvcc -arch=sm_75 q3.cu -o q3

# %%
# !./q3
# Out:
# Dot Product: 2048

# %% [markdown]
# Q3 cpu code

# %%
# %%writefile q3_cpu.cu
# #include <iostream>
# #include <vector>
# using namespace std;
#
# int main() {
#     int N = 1024;
#
#     vector<int> A(N, 1);
#     vector<int> B(N, 2);
#
#     int result = 0;
#
#     for (int i = 0; i < N; i++)
#     {
#         result += A[i]*B[i];
#     }
#
#     cout << "Dot Product: " << result << endl;
# }
# Out:
# Writing q3_cpu.cu

# %%
# !nvcc q3_cpu.cu -o q3_cpu
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./q3_cpu
# Out:
# Dot Product: 2048

# %% [markdown]
# Q4

# %%
# %%writefile q4.cu
#
# #include <iostream>
# using namespace std;
#
# __global__ void matmul(int *A, int *B, int *C) {
#     int row = threadIdx.y;
#     int col = threadIdx.x;
#
#     int sum = 0;
#     for (int k = 0; k < 16; k++)
#         sum += A[row*16 + k] * B[k*16 + col];
#
#     C[row*16 + col] = sum;
# }
#
# int main() {
#     int A[256], B[256], C[256];
#
#     for(int i=0;i<256;i++){
#         A[i]=1; B[i]=1;
#     }
#
#     int *dA,*dB,*dC;
#     cudaMalloc(&dA,256*sizeof(int));
#     cudaMalloc(&dB,256*sizeof(int));
#     cudaMalloc(&dC,256*sizeof(int));
#
#     cudaMemcpy(dA,A,256*sizeof(int),cudaMemcpyHostToDevice);
#     cudaMemcpy(dB,B,256*sizeof(int),cudaMemcpyHostToDevice);
#
#     dim3 threads(16,16);
#     matmul<<<1,threads>>>(dA,dB,dC);
#
#     cudaMemcpy(C,dC,256*sizeof(int),cudaMemcpyDeviceToHost);
#
#     for (int i = 0; i < 16; i++)
#     {
#       for (int j = 0; j < 16; j++)
#       {
#         cout << C[i*16 + j] << "  ";
#       }
#       cout << endl;
#     }
#
# }
# Out:
# Overwriting q4.cu

# %%
# !nvcc q4.cu -o q4
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./q4
# Out:
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# 16  16  16  16  16  16  16  16  16  16  16  16  16  16  16  16
# ...

# %% [markdown]
# Q5 Cuda code

# %%
# %%writefile q5_cuda.cu
# #include <stdio.h>
#
# __global__ void add(int *a, int *b, int *c)
# {
#   int i = blockIdx.x*blockDim.x + threadIdx.x;
#   c[i] = a[i] + b[i];
# }
#
# int main()
# {
#   int N = 5000000;
#   int a[N];
#   int b[N];
#   int c[N];
#
#   for (int i = 0; i < N; i++)
#   {
#     a[i] = i*1.0f;
#     b[i] = i*2.0f;
#   }
#   int *d_a, *d_b, *d_c;
#   int size = N*sizeof(int);
#   cudaMalloc((void **) &d_a, size);
#   cudaMalloc((void **) &d_b, size);
#   cudaMalloc((void **) &d_c, size);
#
#   cudaMemcpy(d_a, a, size, cudaMemcpyHostToDevice);
#   cudaMemcpy(d_b, b, size, cudaMemcpyHostToDevice);
#
#   add<<<32, 32>>>(d_a, d_b, d_c);
#
#   cudaMemcpy(c, d_c, size, cudaMemcpyDeviceToHost);
#   for (int i = 0; i < 5; i++)
#   {
#     printf("C[%d] = %d\n", i, c[i]);
#   }
#   cudaFree(d_a);
#   cudaFree(d_b);
#   cudaFree(d_c);
#   return 0;
# }
# Out:
# Writing q5_cuda.cu

# %%
# !nvcc q5_cuda.cu -o q5_cuda
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./q5_cuda

# %% [markdown]
# Q6

# %%
# %%writefile q6.cu
# #include <thrust/device_vector.h>
# #include <thrust/reduce.h>
# #include <iostream>
#
# int main() {
#     thrust::device_vector<int> A(10);
#
#     for(int i=0;i<10;i++) A[i]=i+1;
#
#     int sum = thrust::reduce(A.begin(), A.end(), 0);
#
#     std::cout << "Sum = " << sum << std::endl;
# }
# Out:
# Writing q6.cu

# %%
# !nvcc q6.cu -o q6
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./q6
# Out:
# Sum = 55

# %% [markdown]
# Q7

# %%
# %%writefile q7.cu
#
# #include <thrust/device_vector.h>
# #include <thrust/sort.h>
# #include <iostream>
#
# int main() {
#     int arr[8] = {7,2,9,1,5,3,8,4};
#
#     thrust::device_vector<int> A(arr, arr+8);
#
#     thrust::sort(A.begin(), A.end());
#
#     for(int i=0;i<8;i++)
#         std::cout << A[i] << " ";
# }
# Out:
# Writing q7.cu

# %%
# !nvcc q7.cu -o q7
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./q7
# Out:
# 1 2 3 4 5 7 8 9
